# %%
from os import listdir
import numpy as np
import matplotlib.pylab as plt 
from __future__ import division
# %matplotlib inline  

col = 'rgb'

def get_path(cam, plane):
    return "../hist/" + cam + "/plane" + str(plane) + "/"

def list_files(cam, plane):
    path = get_path(cam, plane)
    return [path + file for file in listdir(path)]

def file_len(fname):
    with open(fname) as f:
        for i, l in enumerate(f):
            pass
    return i

def read_array(file_reader, n_lines):
    return [[int(i) for i in file_reader.readline().split()] for _ in range(n_lines)]

def read_file(path):
    n = file_len(path)
    with open(path, 'r') as f:
        res = int(f.readline().split()[0])
        hist = read_array(f, n)
    return np.array(hist), res

def convert_3D(hist, res):
    tens = np.zeros([res, res, res])
    for line in hist:
        tens[line[0], line[1], line[2]] = line[3]
    return np.log10(1+9*tens/np.max(np.max(np.max(tens))))*255

def im_color_weight(im, axis):
    n = len(im)
    if axis == 0:
        return im*(np.array([np.arange(n)]).transpose())/n/np.max(np.max(im))
    else:
        return np.array([np.arange(n)])*im/n/np.max(np.max(im))
    
def colorize(im, x, y):
    output = np.zeros([im.shape[0], im.shape[1], 3])
    for i in range(3):
        if x.lower() == col[i]:
            output[:,:,i] = im_color_weight(im, 0)
        elif y.lower() == col[i]:
            output[:,:,i] = im_color_weight(im, 1)
    return output

def plot_hist(hist3, colored=True, points=[]):
    plt.figure(figsize=[20,10])
    for c in range(len(col)):
        remaining = range(3)
        remaining.remove(c)
        axis = col[remaining[0]]+col[remaining[1]]
        plt.subplot(1,3,c+1)
        if colored:
            plt.imshow(colorize(np.sum(hist3, axis=c), axis[0], axis[1]))
        else:
            plt.imshow(np.sum(hist3, axis=c))
            #lt.imshow(np.log10(1+9*np.sum(hist3, axis=c)))
        legend = []
        for i in range(len(points)):
            p = points[i]
            plt.plot(p[remaining[0]], p[remaining[1]], "+", markersize=10)
            legend += ['cluster ' + str(i)]
        plt.legend(legend)
        plt.title(axis.upper()+" histogram")
        plt.ylabel(axis[0])
        plt.xlabel(axis[1])
        
def average_hist(hist):
    return np.sum(hist, axis=0) / len(hist)

# %%
files = list_files('cam3', 1)

# %%
hist, res = read_file(files[0])
hist
# Out:
# array([[  1,   1,   0,   3],
#        [  1,   1,   1,   3],
#        [  1,   2,   1,  21],
#        [  2,   2,   1,  14],
#        [  2,   2,   2,   6],
#        [  2,   3,   2,  18],
#        [  2,   3,   3,   6],
#        [  3,   3,   2,   9],
#        [  3,   3,   3,  12],
#        [  3,   4,   3,   4],
#        [  4,   3,   3,   1],
#        [  4,   4,   3,   2],
#        [  4,   4,   4,   6],
#        [  4,   5,   4,   4],
#        [  4,   5,   5,   1],
#        [  5,   4,   3,   1],
#        [  5,   5,   4,   5],
#        [  5,   5,   5,  12],
#        [  5,   5,   6,   1],
#        [  5,   6,   5,  12],
#        [  5,   6,   6,   2],
#        [  6,   6,   5,   1],
#        [  6,   6,   6,   7],
#        [  6,   7,   6,   7],
#        [  6,   7,   7,   3],
#        [  6,   8,   7,   1],
#        [  7,   5,   4,   1],
#        [  7,   6,   6,   1],
#        [  7,   7,   6,   4],
#        [  7,   7,   7,   6],
#        [  7,   8,   7,   3],
#        [  7,   8,   8,   1],
#        [  8,   7,   6,   2],
#        [  8,   7,   7,   1],
#        [  8,   8,   6,   1],
#        [  8,   8,   7,   4],
#        [  8,   8,   8,   7],
#        [  8,   8,   9,   1],
#        [  8,   9,   8,   5],
#        [  8,  10,   9,   1],
#        [  9,   8,   7,   2],
#        [  9,   9,   7,   1],
#        [  9,   9,   9,   1],
#        [  9,  10,   9,   2],
#        [  9,  10,  10,   2],
#        [ 10,   7,   4,   2],
#        [ 10,   8,   6,   3],
#        [ 10,  10,  10,   2],
#        [ 10,  11,  11,   2],
#        [ 11,   8,   7,   1],
#        [ 11,   9,   8,   1],
#        [ 11,  11,  12,   1],
#        [ 11,  12,  11,   2],
#        [ 11,  12,  12,   1],
#        [ 12,  10,   7,   1],
#        [ 12,  10,   9,   1],
#        [ 12,  12,  11,   2],
#        [ 12,  12,  12,   1],
#        [ 12,  12,  13,   1],
#        [ 12,  13,  12,   2],
#        [ 12,  13,  13,   5],
#        [ 13,  11,   9,   2],
#        [ 13,  13,  13,   4],
#        [ 13,  13,  14,   1],
#        [ 13,  14,  14,   2],
#        [ 14,  14,  13,   2],
#        [ 14,  15,  14,   2],
#        [ 14,  15,  15,   5],
#        [ 15,  11,   7,   2],
#        [ 15,  12,   8,   1],
#        [ 15,  13,  11,   1],
#        [ 15,  14,  13,   1],
#        [ 15,  15,  15,   1],
#        [ 15,  16,  15,   2],
#        [ 15,  16,  16,   4],
#        [ 16,  12,   8,   7],
#        [ 16,  13,   8,   2],
#        [ 16,  13,   9,   2],
#        [ 16,  13,  10,   1],
#        [ 16,  14,  12,   1],
#        [ 16,  16,  15,   1],
#        [ 16,  16,  16,   2],
#        [ 16,  16,  17,   2],
#        [ 16,  17,  16,   3],
#        [ 16,  17,  17,   9],
#        [ 16,  18,  17,   1],
#        [ 17,  12,   8,   1],
#        [ 17,  13,   8,   4],
#        [ 17,  13,   9,  13],
#        [ 17,  13,  10,   2],
#        [ 17,  14,  10,   1],
#        [ 17,  17,  16,   2],
#        [ 17,  17,  17,   3],
#        [ 17,  17,  18,   2],
#        [ 17,  18,  17,   3],
#        [ 17,  18,  18,   7],
#        [ 18,  14,   9,   1],
#        [ 18,  14,  10,   6],
#        [ 18,  15,  11,   2],
#        [ 18,  17,  17,   1],
#        [ 18,  18,  19,   2],
#        [ 18,  19,  18,   5],
#        [ 18,  19,  19,   5],
#        [ 18,  20,  20,   1],
#        [ 19,  15,  11,  10],
#        [ 19,  16,  11,   2],
#        [ 19,  16,  12,   7],
#        [ 19,  16,  13,   3],
#        [ 19,  16,  14,   1],
#        [ 19,  17,  14,   2],
#        [ 19,  17,  15,   1],
#        [ 19,  19,  18,   4],
#        [ 19,  19,  19,   3],
#        [ 19,  19,  20,   1],
#        [ 19,  20,  18,   1],
#        [ 19,  20,  19,   6],
#        [ 19,  20,  20,   6],
#        [ 20,  16,  11,   1],
#        [ 20,  16,  12,   4],
#        [ 20,  17,  14,   2],
#        [ 20,  18,  16,   1],
#        [ 20,  18,  17,   2],
#        [ 20,  19,  17,   1],
#        [ 20,  19,  18,   1],
#        [ 20,  20,  20,   1],
#        [ 20,  20,  21,   1],
#        [ 20,  21,  19,   1],
#        [ 20,  21,  20,   4],
#        [ 20,  21,  21,   8],
#        [ 20,  22,  21,   1],
#        [ 21,  18,  16,   1],
#        [ 21,  19,  16,   1],
#        [ 21,  19,  17,   2],
#        [ 21,  19,  18,   2],
#        [ 21,  20,  18,   1],
#        [ 21,  20,  19,   1],
#        [ 21,  21,  20,   4],
#        [ 21,  21,  21,   6],
#        [ 21,  21,  22,   3],
#        [ 21,  22,  21,   6],
#        [ 21,  22,  22,   8],
#        [ 22,  20,  18,   1],
#        [ 22,  21,  19,   1],
#        [ 22,  22,  20,   2],
#        [ 22,  22,  21,   5],
#        [ 22,  22,  22,  12],
#        [ 22,  22,  23,   2],
#        [ 22,  23,  22,  29],
#        [ 22,  23,  23,   3],
#        [ 22,  24,  23,   2],
#        [ 23,  22,  21,   1],
#        [ 23,  23,  21,   1],
#        [ 23,  23,  22,   3],
#        [ 23,  23,  23,   8],
#        [ 23,  23,  24,   1],
#        [ 23,  24,  23,  30],
#        [ 23,  24,  24,  13],
#        [ 23,  24,  25,   1],
#        [ 23,  25,  24,   2],
#        [ 24,  23,  22,   1],
#        [ 24,  23,  23,   3],
#        [ 24,  24,  23,   5],
#        [ 24,  24,  24,  12],
#        [ 24,  25,  24,  34],
#        [ 24,  25,  25,  21],
#        [ 24,  26,  25,   2],
#        [ 24,  26,  26,   2],
#        [ 25,  24,  24,   2],
#        [ 25,  25,  24,   6],
#        [ 25,  25,  25,  16],
#        [ 25,  25,  26,   7],
#        [ 25,  26,  25,  14],
#        [ 25,  26,  26,  56],
#        [ 25,  26,  27,  18],
#        [ 25,  27,  26,   1],
#        [ 25,  27,  27,   1],
#        [ 26,  25,  25,   1],
#        [ 26,  26,  25,   1],
#        [ 26,  26,  26,  66],
#        [ 26,  26,  27,  10],
#        [ 26,  27,  26,  45],
#        [ 26,  27,  27,  55],
#        [ 26,  27,  28,  11],
#        [ 26,  28,  27,   2],
#        [ 26,  28,  28,   3],
#        [ 27,  27,  27,  14],
#        [ 27,  27,  28,  15],
#        [ 27,  28,  27,  17],
#        [ 27,  28,  28, 103],
#        [ 27,  28,  29,   6],
#        [ 27,  29,  28,   3],
#        [ 27,  29,  29,   1],
#        [ 28,  28,  28,  18],
#        [ 28,  28,  29,   7],
#        [ 28,  29,  28,  18],
#        [ 28,  29,  29,  51],
#        [ 29,  29,  29,   6],
#        [ 29,  29,  30,   6],
#        [ 29,  30,  29,   1],
#        [ 29,  30,  30,  16],
#        [ 30,  30,  30,  39],
#        [ 30,  31,  30,   2]])

# %%
hist3 = convert_3D(hist, res)
hist3.shape
# Out:
# (32, 32, 32)

# %%
colored=colorize(np.sum(hist3, axis=0), 'r', 'b')
colored.shape
# Out:
# (32, 32, 3)

# %%
im=np.zeros([10,10,3])
im[:,:,0]=im_color_weight(np.ones([10,10]), 0)
im[:,:,1]=im_color_weight(np.ones([10,10]), 1)
plt.imshow(im[:,:,:])

# %%
plt.imshow(colorize(np.ones([10,10]), 'r', 'g'))

# %%
plot_hist(hist3, 0)

# %%
_cams = ['fix', 'cam3']
_planes = [1, 2, 3]

for plane in _planes:
    print("plane" + str(plane))
    for cam in _cams:
        print("\t" + cam)
        files = list_files(cam, plane)
        #ex = np.random.choice(range(len(files)))
        #print("\t" + files[ex])
        sum_hist = []
        for f in files:
            hist, res = read_file(files[0])
            hist3 = convert_3D(hist, res)
            if sum_hist == []:
                sum_hist = hist3
            else:
                sum_hist += hist3
        plot_hist(hist3 / len(files), 0)
# Out:
# plane1
# 	fix
# /users/promo2017/smaillot/.local/lib/python2.7/site-packages/ipykernel_launcher.py:15: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   from ipykernel import kernelapp as app
# 	cam3
# plane2
# 	fix
# 	cam3
# plane3
# 	fix
# 	cam3

# %%
from sklearn.cluster import KMeans

hist, res = read_file(process_hist(files[0]))
classified = KMeans(n_clusters=3).fit(hist)

# %%
print classified.labels_
print classified.cluster_centers_
# Out:
# [2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2 2
#  2 2 2 2 2 2 2 2 2 2 0 0 0 2 0 0 0 2 2 0 0 2 2 0 2 2 2 1 2]
# [[ 27.11111111  27.44444444  26.88888889  46.55555556]
#  [ 30.          30.          30.         182.        ]
#  [ 17.375       17.35714286  16.53571429   2.625     ]]

# %%
for plane in _planes:
    print("plane" + str(plane))
    for cam in _cams:
        print("\t" + cam)
        files = list_files(cam, plane)
        #ex = np.random.choice(range(len(files)))
        #print("\t" + files[ex])
        sum_hist = []
        for f in files:
            hist, res = read_file(files[0])
            hist3 = convert_3D(hist, res)
            if sum_hist == []:
                sum_hist = hist3
            else:
                sum_hist += hist3
        plot_hist(hist3 / len(files), 0, points=classified.cluster_centers_)
# Out:
# plane1
# 	fix
# /users/promo2017/smaillot/.local/lib/python2.7/site-packages/ipykernel_launcher.py:12: DeprecationWarning: elementwise == comparison failed; this will raise an error in the future.
#   if sys.path[0] == '':
# 	cam3
# plane2
# 	fix
# 	cam3
# plane3
# 	fix
# 	cam3
