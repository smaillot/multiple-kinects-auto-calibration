# %%
import numpy as np
import matplotlib.pylab as plt
from scipy.stats import kurtosis
# %matplotlib inline

class Data():
    
    def __init__(self, data):
        self.data = data
        self.shape = self.data.shape
        self.t = self.extract_t()
        self.tn = self.extract_tn()
        self.q = self.extract_q()
        self.th = self.extract_th()
        
    def __str__(self):
        self.shape = self.data.shape
        return "{} lines of {} variables".format(self.shape[0], self.shape[1])
        
    def extract_t(self):
        return self.data[:,:3]*1000
        
    def extract_tn(self):
        return np.linalg.norm(self.t, axis=1)
    
    def extract_q(self):
        return self.data[:,3:6]
    
    def extract_th(self):
        return self.data[:,6]*180/np.pi
    
    def cut_serie(self, serie, indexes):
        return np.array([x for i, x in enumerate(serie) if i in indexes])
    
    def cut(self, indexes, verbose=True):
        initial = self.data.shape[0]
        self.data = self.cut_serie(self.data, indexes)
        self.t = self.cut_serie(self.t, indexes)
        self.tn = self.cut_serie(self.tn, indexes)
        self.q = self.cut_serie(self.q, indexes)
        self.th = self.cut_serie(self.th, indexes)
        final = self.data.shape[0]
        if verbose:
            print("Reducing data from {} to {} ({:.2f}%)".format(initial, final, 100*final/initial))
        
    def get_stat(self, serie):
        return np.mean(serie), np.std(serie)

class Reader():
    
    def __init__(self, file):
        self.file = file
        self.data = Data(self.read_log())
        self.update_dim() 
        print(self)
        self.auto()
        
    def __str__(self):
        self.update_dim()
        return("File {} contains {}.".format(self.file, self.data))
        
    def read_log(self):
        with open(self.file) as f:
            data = [[float(n) for n in l.split()] for l in f]
        return np.array(data)
    
    def update_dim(self):
        self.dim = self.data.shape
        self.rows, self.cols = self.dim
        
    def hist(self, data, bins=100, title='', x='', y='samples (in %)'):
        plt.figure(figsize=[10,5])
        _ = plt.hist(data, bins, normed=1)
        m, s = self.data.get_stat(data)
        plt.title(title + ' (mean: {:.2f}, std: {:.2f})'.format(m, s))
        plt.xlabel(x)
        plt.ylabel(y)
        
    def plot_time(self, data, title='', x='samples', y='', std=[0, 1, 3]):
        plt.figure(figsize=[10,5])
        m, s = self.data.get_stat(data)
        plt.plot(data, label='measures')
        for x in std:
            if x == 0:
                plt.plot([0,len(data)], [m, m], 'r', label='mean')
            else:
                col = (1, 1-1/(1+x), 0)
                plt.plot([0,len(data)], [m+x*s, m+x*s], '--', c=col, label='{:d} \sigma'.format(x))
                plt.plot([0,len(data)], [m-x*s, m-x*s], '--', c=col, label='_nolegend_')
        plt.title(title)
        plt.xlabel(x)
        plt.ylabel(y)
        plt.legend()
        
    def cut_percentile(self, data, bounds):
        if len(bounds) == 1:
            b = [bounds, 100-bounds]
        else:
            b = bounds
        b.sort()
        p = [np.percentile(hist[1], b[0]), np.percentile(hist[1], b[1])]
        return np.array([i for i in data if (i >= p[0] and i <= p[1])]), np.array([i for i in range(len(data)) if (data[i] >= p[0] and data[i] <= p[1])])
    
    def cut(self, data, bounds):
        bounds.sort()
        return np.array([i for i in data if (i >= bounds[0] and i <= bounds[1])]), np.array([i for i in range(len(data)) if (data[i] >= bounds[0] and data[i] <= bounds[1])])
    
    def outliers(self, ref, bounds):
        _, indexes = self.cut(ref, bounds)
        self.data.cut(indexes, verbose=True)
        
    def auto(self):
        self.outliers(self.data.tn, [-200, 200])
        self.plot_time(self.data.tn)
        self.hist(self.data.tn, 100, 'Translation error', 'distance (in mm)')
        self.hist(self.data.th, 100, 'Rotation error', 'angle (in °)')

# %%
R = Reader('cam3_cam2_nofiltering.log')
# Out:
# File cam3_cam2_nofiltering.log contains 1317 lines of 7 variables.
# Reducing data from 1317 to 1253 (95.14%)

# %%
R = Reader('cam3_cam2-average.log')
# Out:
# File cam3_cam2-average.log contains 85 lines of 7 variables.
# Reducing data from 85 to 85 (100.00%)

# %%
R = Reader('cam3_cam2_filter01.log')
# Out:
# File cam3_cam2_filter01.log contains 15 lines of 7 variables.
# Reducing data from 15 to 15 (100.00%)

# %%
hist = plt.hist(cam12_t)

# %%
cam12_t_filtered = np.array([x for x in cam12_t if (x >= 0 and x <= 200) ])
cam12_t_filtered.shape
# Out:
# (1253,)

# %%
hist = plt.hist(cam12_t_filtered, 100, normed=1)
plt.title('Cam3 registration distance error (compared to AR marker extrinsic calibration) - ' + str(cam12_t_filtered.shape[0]) + ' samples')
plt.xlabel('distance (in mm)')
plt.ylabel('number of samples (in %)')

# %%
kurtosis(cam12_t_filtered)
# Out:
# 18.415096791370793

# %%
np.mean(cam12_t_filtered)
# Out:
# 112.66727089037175

# %%
np.std(cam12_t_filtered)
# Out:
# 9.114343284267353

# %%
gauss = np.random.normal(np.mean(cam12_t_filtered), np.std(cam12_t_filtered), 1000000)

# %%
plt.figure(figsize=[10,5])
hist1 = plt.hist(gauss, 100, normed=1, color=[0,0,0,0.5])
hist2 = plt.hist(cam12_t_filtered, 100, normed=1, color=[0,0.3,0.8,0.8])
tit='compared to normal, mean = ' + str(np.round(np.mean(cam12_t_filtered), 1)) + 'mm, std = ' + str(np.round(np.std(cam12_t_filtered),1)) + 'mm'
plt.title('Cam3 registration distance error (compared to AR marker extrinsic calibration) - ' + str(cam12_t_filtered.shape[0]) + ' samples\n'+tit)
plt.xlabel('distance (in mm)')
plt.ylabel('number of samples (in %)')

# %%
plt.plot(hist1[1][:-1], hist1[0])
plt.plot(hist2[1][:-1], hist2[0])
plt.legend(['normal', 'measures'])

# %%
class LogReader:
    def __init__(self, file, name=''):
        if name == '':
            name = file.split('/')[-1].split('.')[0]
        self.name = name
        with open(file) as f:
            print("Loading data...")
            data = []
            for i, l in enumerate(f):
                if i%1000 == 0 and i!= 0:
                    print(i)
                data.append([float(x) for x in l.split()])
            self.data = np.array(data)
        self.v_t = self.data[:,:3]
        self.t = np.linalg.norm(self.v_t, axis=1)
        self.a_t = self.data[:,3:6]
        self.th = self.data[:,6] * 180 / 3.14159
        
    def cut_outliers(self, vec):
        return np.array([x for x in vec if (x >= np.percentile(vec, 1) and x <= np.percentile(vec, 99)) ])
    
    def stats(self, vec):
        vec = self.cut_outliers(vec)
        return np.mean(vec), np.std(vec), kurtosis(vec)
    
    def plot_hist(self, vec):
        vec = self.cut_outliers(vec)
        plt.hist(vec, 100)

# %%
LR = LogReader('cam1_cam2.log')
print(LR.stats(LR.t))
LR.plot_hist(LR.t)
# Out:
# Loading data...
# 1000
# 2000
# 3000
# 4000
# (0.0907704468918678, 0.0330349572588326, 105.8213748786084)

# %%
print(LR.stats(LR.th))
LR.plot_hist(LR.th)
# Out:
# (5.166194379953464, 0.9452111624750924, 1.0985909766880066)
